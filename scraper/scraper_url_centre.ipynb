# %% [markdown]
# ## Data Scraper
# The dataset here is for demonstration, scraped with a single keyword.
# We used multiple keywords to reach the desirable data size.

# %% [markdown]
# ### Install and Import Required Libraries

# %%
# %pip install -r requirements.txt

# %%
import requests
# from bs4 import BeautifulSoup
import json
from newsapi import NewsApiClient
# from itertools import product
import pandas as pd
import os
import glob
import trafilatura
import time
import random
import csv
# from requests.adapters import HTTPAdapter
# from urllib3.util.retry import Retry

# %% [markdown]
# ### API  Key

# %%
key = input()
print(f"API KEY = {key}")
# Out:
# API KEY = 39520930797f48f29aa1abf9ec3a5cab

# %% [markdown]
# ### Search for Unique IDs (Names) of the News Providers (in English)

# %%
newsapi = NewsApiClient(api_key=key)
sources = newsapi.get_sources(language="en")

ids = [source['id'] for source in sources['sources']]

# Write out a text file of all source ids
with open('source_ids.txt', 'w', encoding='utf-8') as f:
    for id in ids:
        f.write(f"{id}\n")

# This is just for checking the data structure        
with open('sources.txt', 'w', encoding='utf-8') as f:
    f.write(json.dumps(sources, indent=2))

# %% [markdown]
# ### Scraping Example

# %%
# An example of using NewsAPI to search for articles with keyword "trump" in all english providers
# Free account limits the result to 100 articles when there is more
url = (f'https://newsapi.org/v2/everything?'
       f'q=trump&'
       f'language=en&'
       f'apiKey={key}')
response = requests.get(url)
result = response.json()
result
# Out:
# {'status': 'ok',
#  'totalResults': 67020,
#  'articles': [{'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'David Gilbert',
#    'title': 'How Donald Trump Lost Control of the Epstein Spin Cycle',
#    'description': "Donald Trump has spent years benefiting from the QAnon's Jeffrey Epstein obsession. That’s all changing.",
#    'url': 'https://www.wired.com/story/how-donald-trump-lost-control-of-the-epstein-spin-cycle/',
#    'urlToImage': 'https://media.wired.com/photos/691d1d514b7bcaeae916085d/191:100/w_1280,c_limit/politics_epstein_conspiracies_trump.jpg',
#    'publishedAt': '2025-11-19T16:00:00Z',
#    'content': 'For almost a decade, President Donald Trump has managed to control the conspiracy theory spin around disgraced financier and registered sex offender Jeffrey Epstein. The conspiracy theories benefited… [+2344 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Mila Fiordalisi',
#    'title': 'Europe Is Bending the Knee to the US on Tech Policy',
#    'description': "The Trump administration's pressure on European regulators is having an impact, with fewer restrictions on Big Tech and canceled measures.",
#    'url': 'https://www.wired.com/story/europe-bends-us-digital-policies-eu-ai-act/',
#    'urlToImage': 'https://media.wired.com/photos/691ce9938dd4b1eceaaa27e7/191:100/w_1280,c_limit/2226607565',
#    'publishedAt': '2025-11-24T07:00:00Z',
#    'content': 'Almost everything is on hiatus. The EU AI Act, Digital Services Act, and Digital Markets Act are all at risk. The European Commission is preparing to end the year with virtually no movement on its mo… [+5349 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Jess Weatherbed',
#    'title': 'Trump re-nominates billionaire Jared Isaacman to lead NASA',
#    'description': 'President Donald Trump has once again picked tech billionaire Jared Isaacman to be the next NASA Administrator, five months after pulling the initial nomination he made last year. Isaacman, an Elon Musk ally and commercial astronaut who has travelled into orb…',
#    'url': 'https://www.theverge.com/news/814035/donald-trump-jared-isaacman-nasa-nomination',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/gettyimages-2187705037.jpg?quality=90&strip=all&crop=0%2C14.01990937478%2C100%2C71.96018125044&w=1200',
#    'publishedAt': '2025-11-05T10:47:34Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nAfter pulling his nomination in May, the President has again decided that Isaacman is the best man for the job.\r\nAfter pulling his nomination in May, the Preside… [+3199 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Emma Roth',
#    'title': 'Senator Warren presses Trump admin on potential AI bailout plans',
#    'description': 'Senator Elizabeth Warren (D-MA) is pressing the Trump administration for more information on potential plans to “prop up” major AI companies with money from taxpayers. In a letter to David Sacks, the White House special advisor for AI and Crypto, and Michael …',
#    'url': 'https://www.theverge.com/news/823136/senator-elizabeth-warren-openai-trump-bailout',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/STK417_MONEY_CVIRGINIA_B.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200',
#    'publishedAt': '2025-11-18T18:01:46Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nTrumps ties to tech execs and donors raise concerns that the admin might prop up companies like OpenAI, Warren says.\r\nTrumps ties to tech execs and donors raise … [+4319 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Dominic Preston',
#    'title': 'Why we’re going to keep talking about the Trump phone',
#    'description': 'For the past couple of weeks, I’ve been asking — repeatedly — where the promised Trump phone is, whether it exists, and what happened to all the money people have already paid for deposits. And I’m going to keep doing that every week for the foreseeable futur…',
#    'url': 'https://www.theverge.com/news/820887/why-we-keep-writing-about-trump-phone-t1',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/Vrg_illo_trump_phone_np.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-11-14T16:34:19Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nIts not because were fans.\r\nIts not because were fans.\r\nby\r\nDominic PrestonClose\r\nDominic Preston\r\nPosts from this author will be added to your daily email diges… [+3977 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Tim Marchman, Leah Feiger',
#    'title': 'Jeffrey Epstein Claimed Intimate Knowledge of Donald Trump’s Views in Texts With Bill Gates Adviser',
#    'description': 'In text messages from 2017, Jeffrey Epstein seemingly represented himself as positioned to pass information from the Trump White House to Bill Gates through an intermediary.',
#    'url': 'https://www.wired.com/story/jeffrey-epstein-claimed-intimate-knowledge-of-donald-trumps-views-in-texts-with-bill-gates-adviser/',
#    'urlToImage': 'https://media.wired.com/photos/6915e149686517084cfcf629/191:100/w_1280,c_limit/GettyImages-1393977679.jpg',
#    'publishedAt': '2025-11-13T20:19:22Z',
#    'content': 'The next day, she sent Epstein a link to an article in Commentary about Trumps election and the American economy. Good article for trump to see, she wrote.\r\nOn March 4, Melanie messaged Epstein. Bg m… [+1967 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Joel Khalili',
#    'title': "Trump's CZ Pardon Has the Crypto World Bracing for Impact",
#    'description': 'The Trump administration has recast Binance founder CZ as a martyr—and his pardon may have unintended consequences for the US crypto industry.',
#    'url': 'https://www.wired.com/story/trumps-cz-pardon-has-the-crypto-world-bracing-for-impact/',
#    'urlToImage': 'https://media.wired.com/photos/6902552b4e7c8c237645e4a1/191:100/w_1280,c_limit/What-CZ-and-Binance-Can-Do-Next-Business-2210817298.jpg',
#    'publishedAt': '2025-11-03T19:21:17Z',
#    'content': 'Changpeng Zhao, the multibillionaire founder of crypto exchange Binance, spent four months last year locked in a federal prison. After US president Donald Trump pardoned Zhao in October, the governme… [+2461 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Torpey',
#    'title': 'Homeland Security Is Reportedly Probing Bitcoin Mining Giant Bitmain for National Security Reasons',
#    'description': "And there's an additional Trump family connection.",
#    'url': 'https://gizmodo.com/homeland-security-is-reportedly-probing-bitcoin-mining-giant-bitmain-for-national-security-reasons-2000689746',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/10/sec-bitcoin-hack-arrest.jpg',
#    'publishedAt': '2025-11-23T10:00:14Z',
#    'content': 'According to a new report from Bloomberg, federal authorities have quietly been digging into Bitmain, the Beijing-based bitcoin mining hardware manufacturing giant, over fears that its devices could … [+5367 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Ali Winston',
#    'title': 'An Anarchist’s Conviction Offers a Grim Foreshadowing of Trump’s War on the ‘Left’',
#    'description': 'As the Trump administration ramps up its targeting of left-leaning people and groups, the prosecution and harsh sentencing of Casey Goonan may provide a glimpse of things to come.',
#    'url': 'https://www.wired.com/story/an-anarchists-conviction-offers-a-grim-foreshadowing-of-trumps-war-on-the-left/',
#    'urlToImage': 'https://media.wired.com/photos/68df11409f9bbd130abacc14/191:100/w_1280,c_limit/Anarchist-Cop-Car-Fire-Security-2218926083.jpg',
#    'publishedAt': '2025-11-03T10:30:00Z',
#    'content': 'By the standards of the San Francisco Bay Areas hard left, Casey Goonans crimes were unremarkable. A police SUV partially burned by an incendiary device on UC Berkeleys campus. A planter of shrubs li… [+3391 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Trump Questions Whether Turkeys He Pardoned Are Really MAHA Because They’re ‘Fat’',
#    'description': '"Secretary Kennedy has formally certified that these are the first ever MAHA turkeys," said Trump.',
#    'url': 'https://gizmodo.com/trump-questions-whether-turkeys-he-pardoned-are-really-maha-because-theyre-fat-2000691550',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/donald-trump-turkey-pardon-nov.-25-2025-1200x675.jpg',
#    'publishedAt': '2025-11-25T19:50:06Z',
#    'content': 'President Donald Trump pardoned two Thanksgiving turkeys on Tuesday, continuing a strange American tradition that has been going on for decades. And while Trump read a speech that included a line abo… [+5810 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Search Epstein’s Emails in the Most Unnerving Way Possible',
#    'description': "It's even easier now to search for names like Trump, Chomsky, and Summers.",
#    'url': 'https://gizmodo.com/search-epsteins-emails-in-the-most-unnerving-way-possible-2000689736',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/03/6b2b665555050bf7f1c6f565591b3dc3.jpg',
#    'publishedAt': '2025-11-22T14:41:27Z',
#    'content': 'Are you curious about the recently released emails of Jeffrey Epstein but don’t feel like clicking through thousands of cumbersome files? There’s now a way to search Epstein’s inbox in a much easier … [+2151 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "The looming election Trump can't afford to lose",
#    'description': 'In a Tennessee district Trump won by 22% last year, the result could prompt Republican panic at a time when Trump is vulnerable.',
#    'url': 'https://www.bbc.com/news/articles/clyzdgqk771o',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/e86b/live/257287c0-ca2c-11f0-8c06-f5d460985095.jpg',
#    'publishedAt': '2025-11-26T00:01:16Z',
#    'content': 'Anthony ZurcherNorth America correspondent, Tennessee\r\nWatch: "We\'re in a pivotal place" - Tennessee voters on Trump\'s performance\r\n"They\'re coming to Tennessee to try to take a congressional seat."\r… [+10831 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'Consider airspace around Venezuela closed, Trump says',
#    'description': "The US cannot legally close another country's airspace, but Trump's comments could deter airlines from operating in Venezuela.",
#    'url': 'https://www.bbc.com/news/articles/c741mpdyw9no',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/e55a/live/b5217f70-cd29-11f0-9f8a-0321935e874a.jpg',
#    'publishedAt': '2025-11-29T16:43:24Z',
#    'content': 'US President Donald Trump has said that the airspace around Venezuela should be considered closed. \r\n"To all Airlines, Pilots, Drug Dealers, and Human Traffickers, please consider THE AIRSPACE ABOVE … [+2432 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Molly Taft',
#    'title': 'The Trump Administration’s Data Center Push Could Open the Door for New Forever Chemicals',
#    'description': 'The EPA is prioritizing review of new chemicals to be used in data centers. Experts say this could lead to the fast approval of new types of forever chemicals—with limited oversight.',
#    'url': 'https://www.wired.com/story/the-trump-administrations-data-center-push-could-open-the-door-for-new-forever-chemicals/',
#    'urlToImage': 'https://media.wired.com/photos/68f61db20c1135aaf20c0288/191:100/w_1280,c_limit/102025_Data-Center-Chemical-Allowances.jpg',
#    'publishedAt': '2025-11-26T12:00:00Z',
#    'content': 'In recent months, the Trump administration has opened a deregulatory floodgate in the name of building more data centers. Among other things, this has involved ordering rollbacks of clean water regul… [+2755 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': '60 Minutes Edited Out Trump’s Response to Questions About Crypto Corruption',
#    'description': '"I\'d rather not have you ask the question," Trump said in a deleted portion of the interview.',
#    'url': 'https://gizmodo.com/trump-60-minutes-edited-crypto-binance-2000680807',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/trump-60-minutes-1200x675.jpg',
#    'publishedAt': '2025-11-03T20:15:10Z',
#    'content': 'Last month, President Donald Trump pardoned Binance founder Changpeng Zhao, a move that raised plenty of eyebrows given Binance’s promotion of the Trump family’s crypto ventures. Trump was asked abou… [+9083 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tina Nguyen',
#    'title': 'Here’s\xa0the Trump executive order that would ban state AI laws',
#    'description': 'President Donald Trump is considering signing an executive order as soon as Friday that would give the federal government unilateral power over regulating artificial intelligence, including the creation of an "AI Litigation Task Force" overseen by the Attorne…',
#    'url': 'https://www.theverge.com/ai-artificial-intelligence/824608/trump-executive-order-ai-state-laws',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/01/gettyimages-2194990747.jpg?quality=90&strip=all&crop=0%2C10.736864816537%2C100%2C78.526270366927&w=1200',
#    'publishedAt': '2025-11-19T23:03:28Z',
#    'content': '<ul><li></li><li></li></ul>\r\nTrump is launching an all-out broadside against states with strict AI regulations\r\nTrump is launching an all-out broadside against states with strict AI regulations\r\nby\r\n… [+6046 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'Watch: How Tim Davie addressed BBC controversies over the years',
#    'description': "The BBC's director general Tim Davie has resigned over Trump documentary edit.",
#    'url': 'https://www.bbc.com/news/videos/czxk2ed2780o',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/4c76/live/2a1de0a0-bda5-11f0-ae46-bd64331f0fd4.jpg',
#    'publishedAt': '2025-11-09T19:52:24Z',
#    'content': 'Over the span of his career as BBC director general, Tim Davie faced multiple crises including over presenter Gary Lineker, Bob Vylan at Glastonbury and the Gaza: How To Survive A Warzone documentary… [+363 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Are cracks showing inside Trump’s MAGA movement?',
#    'description': 'The growing questions from Republicans on how Trump is running the country',
#    'url': 'https://www.bbc.co.uk/sounds/play/w3ct8byq',
#    'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p0j72y80.jpg',
#    'publishedAt': '2025-11-14T13:06:00Z',
#    'content': 'Available for over a year\r\nFifty year mortgages, recent aid for Argentina, high food prices, a focus on foreign affairs, and Trump telling Fox News that the U.S. needs foreign workers because it does… [+1998 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Will Trump delay releasing the Epstein Files?',
#    'description': 'Donald Trump has urged House Republicans to vote to release the Epstein Files.',
#    'url': 'https://www.bbc.co.uk/sounds/play/p0mhn68x',
#    'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p0j72y80.jpg',
#    'publishedAt': '2025-11-17T19:06:00Z',
#    'content': 'Available for over a year\r\nDonald Trump says he will sign a bill to release the Epstein Files after it passed nearly unanimously through both houses of Congress. Its a notable shift in position from … [+2327 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Tr
chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'US judge says Trump cannot deploy National Guard to Portland',
#    'description': 'The Trump administration did not have a legal basis to use troops to quell immigration protests, the judge wrote in a 106-page ruling.',
#    'url': 'https://www.bbc.com/news/articles/cddrq0plr1zo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/36d1/live/08bcea00-bbf7-11f0-899d-e3ef1f2105c0.jpg',
#    'publishedAt': '2025-11-08T02:54:51Z',
#    'content': 'A US judge will not allow President Donald Trump to deploy National Guard members to the city of Portland, Oregon. \r\nThe ruling is the latest in a weeks-long court battle over whether the president v… [+2589 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'BBC faces fresh claim of misleading Trump edit',
#    'description': "The clip aired on Newsnight in 2022, two years before the Panorama that led to the director-general's resignation.",
#    'url': 'https://www.bbc.com/news/articles/cr5e9erpnzlo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/0c70/live/2f0d5ba0-c0ba-11f0-8669-5560f5c90fbe.png',
#    'publishedAt': '2025-11-13T17:50:40Z',
#    'content': "The BBC was accused of a misleading edit of Donald Trump's 6 January 2021 speech two years before the Panorama sequence that led to the resignation of the director-general.\r\nThe clip aired on Newsnig… [+2406 chars]"},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'Trump calls on House Republicans to release Epstein files',
#    'description': '\'We have nothing to hide," Trump wrote on Truth Social, in reversal after days of fighting proposal to make more of the Epstein files public.',
#    'url': 'https://www.bbc.com/news/articles/cvgv653v1vjo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/68e1/live/d4df66a0-c361-11f0-8669-5560f5c90fbe.jpg',
#    'publishedAt': '2025-11-17T03:10:34Z',
#    'content': 'US President Donald Trump has called on House Republicans to vote to release the Epstein files, in a reversal from his previous position. \r\n"House Republicans should vote to release the Epstein files… [+998 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'Georgia prosecutor drops 2020 election interference case against Trump',
#    'description': 'The state charges were part of the last remaining criminal case against the US president stemming from the 2020 election.',
#    'url': 'https://www.bbc.com/news/articles/czxpd8pv4gyo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1a2d/live/537ff930-6139-11ee-b101-6f93d6dfbcc2.png',
#    'publishedAt': '2025-11-26T16:22:13Z',
#    'content': 'A Georgia prosecutor has dropped the 2020 election-interference case against President Donald Trump.\r\nPete Skandalakis filed a motion to dismiss the case that initially accused Trump and others of pl… [+487 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Tina Nguyen',
#    'title': 'What the leaked AI executive order tells us about the Big Tech power grab',
#    'description': "Hello and welcome back to Regulator. It's been a very long two weeks away from your inboxes, but luckily for us, Big Tech and Big Government did not stop fighting. In fact, it's gotten even spicier. Let's get into it. Last week, I was following up on several …",
#    'url': 'https://www.theverge.com/column/829938/leaked-ai-executive-order-analysis',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/STKP213_DAVID_SACKS_D.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#    'publishedAt': '2025-11-26T15:41:38Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nWhat the leaked AI executive order tells us about the Big Tech power grab\r\nShould states write their own AI laws, or should David Sacks?\r\nby\r\nTina NguyenClose\r\nT… [+16353 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "How Trump could hamper Zohran Mamdani's New York agenda",
#    'description': "Trump has taken a number of actions against Democratic-led cities that experts say could slow Mamdani's goals.",
#    'url': 'https://www.bbc.com/news/articles/cvg4337rxy1o',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/a735/live/5f01d670-bbeb-11f0-8456-eff94716b162.png',
#    'publishedAt': '2025-11-08T12:27:45Z',
#    'content': 'Trump has been attacking Mamdani as a "communist" since he won the New York Democratic primary in June\r\nJust moments after Zohran Mamdani won his battle to become the next mayor of New York City, the… [+8076 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 
chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "'I'll be cheering for him': Takeaways from Trump and Mamdani's surprisingly cordial meeting",
#    'description': 'It was billed as potentially the political showdown of the year. Instead, both men gave one another praise.',
#    'url': 'https://www.bbc.com/news/articles/cvgqd42gl0qo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/10f6/live/0564c790-c72a-11f0-a0c0-8b5d01646a8a.jpg',
#    'publishedAt': '2025-11-21T23:52:51Z',
#    'content': 'Watch: "Ill be cheering for him" - Trump praises Mamdani after first meeting\r\nUS President Donald Trump met New York City\'s newly elected mayor Zohran Mamdani at the White House in what was billed as… [+6014 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Ali Winston',
#    'title': 'Senators Want Extremism Researchers to Surrender Documents Linked to Right-Wing Grudges',
#    'description': "The Senate homeland security committee's chair has asked researchers to turn over troves of documents related to the January 6 attack, vaccines, and more, according to a letter reviewed by WIRED.",
#    'url': 'https://www.wired.com/story/senators-want-extremism-researchers-to-surrender-documents-linked-to-right-wing-grudges/',
#    'urlToImage': 'https://media.wired.com/photos/691df3b7983802611c19de44/191:100/w_1280,c_limit/GettyImages-2217725429.jpg',
#    'publishedAt': '2025-11-21T17:06:49Z',
#    'content': 'A powerful United States Senate committee has requested that multiple academic research centers focused on political extremism hand over years worth of documentation on federal watchlisting programs,… [+2979 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Cornell University Will Pay $60 Million to Unlock Research Funds Frozen by White House',
#    'description': 'The administration has come after researchers at institutions across the country.',
#    'url': 'https://gizmodo.com/cornell-university-will-pay-60-million-to-unlock-research-funds-frozen-by-white-house-2000683157',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/cornell-university-1200x675.jpg',
#    'publishedAt': '2025-11-07T19:05:44Z',
#    'content': 'Cornell University announced Friday that it had reached an agreement with the Trump administration to pay $30 million to restore roughly $250 million in funding that had been withheld from the New Yo… [+4085 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'AJ Dellinger',
#    'title': 'Elon Musk’s xAI Is Getting a Fancy 500-Megawatt Data Center in Saudi Arabia',
#    'description': 'Musk and the Kingdom worked together to buy Twitter, so they already have a nice relationship.',
#    'url': 'https://gizmodo.com/elon-musk-xai-is-getting-a-fancy-500-megawatt-data-center-in-saudi-arabia-2000688344',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/elon-musk-jensen-huang-nov.-19-2025-1200x675.jpg',
#    'publishedAt': '2025-11-19T19:40:20Z',
#    'content': 'Saudi Arabia appears to be fully engaged in a MAGA-washing campaign, buddying up to the Trump administration and its hangers-on to improve its image for billionaires to do business there. It appears … [+2452 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': 'BBC apologises to Trump over Panorama edit but refuses to pay compensation',
#    'description': 'Lawyers for the US president have threatened to sue the corporation for $1bn (£759m).',
#    'url': 'https://www.bbc.com/news/articles/c874nw4g2zzo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/535a/live/63a05d40-c0ab-11f0-ae46-bd64331f0fd4.jpg',
#    'publishedAt': '2025-11-13T20:30:25Z',
#    'content': 'The BBC has apologised to US President Donald Trump for a Panorama episode which spliced parts of a speech together, but rejected his demands for compensation.\r\nThe corporation also said it would not… [+1914 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': 'Americanswers on 5 Live! Why is Donald Trump threatening to sue the BBC for $1 billion?',
#    'description': 'And how will the U.S. government shutdown end?',
#    'url': 'https://www.bbc.co.uk/sounds/play/p0mfxsk5',
#    'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p0j72y80.jpg',
#    'publishedAt': '2025-11-10T20:07:00Z',
#    'content': 'Available for over a year\r\nPresident Donald Trump has threatened to sue the BBC for $1 billion over how the editing of his speech in a Panorama documentary, calling it "false and defamatory". The BBC… [+1999 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "Trump says US will 'permanently pause migration' from 'third world countries'",
#    'description': 'The president did not name which countries would be affected, but vowed to remove anyone "not a net asset" to the US.',
#    'url': 'https://www.bbc.com/news/articles/cdxweyy157go',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/cbce/live/557652d0-cc16-11f0-9fb5-5f3a3703a365.jpg',
#    'publishedAt': '2025-11-28T07:16:15Z',
# ...
#    'url': 'https://www.npr.org/2025/11/14/nx-s1-5608004/bbc-apology-trump-speech',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/7865x4424+0+409/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fe6%2F36%2Fc8582e694a9f8ea620628a251f85%2Fap25316389227050.jpg',
#    'publishedAt': '2025-11-14T11:41:47Z',
#    'content': "Britain's public broadcaster, the BBC, has issued a personal apology to former U.S. President Donald Trump over a misleading edit of his Jan. 6, 2021 speech in a documentary broadcast under its often… [+5417 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Ece Yildirim',
#    'title': 'Marc Andreessen-Backed Super-PAC Pours Millions Into Fighting State AI Regulations',
#    'description': 'The advocacy offshoot wants a "uniform national approach."',
#    'url': 'https://gizmodo.com/marc-andreessen-backed-super-pac-pours-millions-into-fighting-state-ai-regulations-2000691430',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/04/f95161a3e09c9c8bfc8406d4d4a30e3e-e1764091660126-1200x675.jpg',
#    'publishedAt': '2025-11-25T17:45:38Z',
#    'content': 'A pro-AI super PAC is investing millions into creating an AI-friendly regulatory environment in the United States.\r\nCalled “Leading The Future,” the super PAC is backed by venture capital firm Andree… [+3703 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Aditi Bharade',
#    'title': 'The Musk-Trump feud is thawing, again',
#    'description': 'Musk made his first public appearance at the White House in months, and later thanked Trump on X for "all he has done for America and the world."',
#    'url': 'https://www.businessinsider.com/elon-musk-donald-trump-saudi-prince-dinner-feud-thaw-2025-11',
#    'urlToImage': 'https://i.insider.com/691e7b41e1a9cbb014de9340?width=1200&format=jpeg',
#    'publishedAt': '2025-11-20T05:05:17Z',
#    'content': "The Trump-Musk feud seems to be thawing.Kevin Dietsch/Getty Images\r\n<ul><li>Elon Musk and Donald Trump are extending olive branches to each other.</li><li>Musk was at Trump's CEO-studded White House … [+2388 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'Bryan Metzger',
#    'title': 'Republicans to Trump: No $2,000 tariff checks',
#    'description': "Trump says that $2,000 tariff checks are coming mid-2026. His GOP allies on Capitol Hill aren't so sure.",
#    'url': 'https://www.businessinsider.com/donald-trump-2000-tariff-rebate-checks-republicans-2025-11',
#    'urlToImage': 'https://i.insider.com/691b96c789026fbb4d0dd176?width=1200&format=jpeg',
#    'publishedAt': '2025-11-22T10:45:01Z',
#    'content': 'Trump says $2,000 tariff checks are coming mid-2026. His GOP allies on Capitol Hill have other ideas.Jim Watson / AFP via Getty Images\r\n<ul><li>Trump has proposed sending $2,000 tariff checks to Amer… [+5014 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "Joy precedes scrutiny: Inside Mamdani's victory party",
#    'description': "BBC News correspondent Nada Tawfik reports from inside the Zohran Mamdani's mayoral victory party.",
#    'url': 'https://www.bbc.com/news/videos/cj97rprxllmo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1fd2/live/52ba4db0-ba1b-11f0-ba75-093eca1ac29b.jpg',
#    'publishedAt': '2025-11-05T07:50:24Z',
#    'content': "The BBC's Nada Tawfik reported from inside winning New York City mayoral candidate Zohran Mamdani's victory party.\r\nMamdani, 34, became the first Muslim mayor and youngest person in over a century to… [+170 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Ece Yildirim',
#    'title': 'Republicans and Europe Agree: It’s Time to Make Life Easier for AI Companies',
#    'description': "Trump's anti-regulation push seems to be bearing fruit globally.",
#    'url': 'https://gizmodo.com/republicans-and-europe-agree-its-time-to-make-life-easier-for-ai-companies-2000688314',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/GettyImages-2212182282-1200x675.jpg',
#    'publishedAt': '2025-11-20T14:20:25Z',
#    'content': 'The White House and European leaders rarely see eye-to-eye on much, but they are gradually finding common ground on the issue of deregulating AI companies to spur even more unfettered development.\r\nT… [+4886 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bmetzger@insider.com (Bryan Metzger)',
#    'title': "Trump says he'd feel comfortable living in Zohran Mamdani's NYC",
#    'description': 'After meeting in the Oval Office, Trump and NYC Mayor-elect Zohran Mamdani sounded a largely conciliatory note.',
#    'url': 'https://www.businessinsider.com/trump-zohran-mamdani-white-house-meeting-federal-funding-2025-11',
#    'urlToImage': 'https://i.insider.com/6920dbd4abd5e944effb4b37?width=1200&format=jpeg',
#    'publishedAt': '2025-11-21T21:39:35Z',
#    'content': 'Zohran Mamdani appears to have charmed Donald Trump.\r\nFollowing a meeting with the New York City mayor-elect in the Oval Office on Friday afternoon, the president had nothing but nice things to say a… [+2492 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Mike Pearl',
#    'title': '438 Reasons to Doubt that David Sacks Should Work for the Federal Government',
#    'description': 'His investments may expose him to conflicts of interest. They also probably distort common sense.',
#    'url': 'https://gizmodo.com/david-sacks-possible-conflicts-2000693709',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/david-sacks-1200x675.jpg',
#    'publishedAt': '2025-12-01T10:00:10Z',
#    'content': 'A new report from the New York Times digs into the financial disclosures of President Trumps AI and crypto czar, PayPal Mafia founding member David Sacks, and finds ample reason to doubt that he coul… [+4906 chars]'},
#   {'source': {'id': None, 'name': 'Reality Tea'},
#    'author': 'Bikki Sharma',
#    'title': 'Melania Trump ‘Deeply Uncomfortable’ Because of This — Source',
#    'description': 'Sources claim that Melania Trump is reportedly upset after Eric Trump publicly repeated what he claimed Barron Trump had said to former President Joe Biden...',
#    'url': 'https://www.realitytea.com/2025/11/20/melania-trump-furious-family-member-barron/',
#    'urlToImage': 'https://media.zenfs.com/en/reality_tea_694/ef1b10687a737a81056999fba563c82d',
#    'publishedAt': '2025-11-20T13:36:43Z',
#    'content': 'Sources claim that Melania Trump is reportedly upset after Eric Trump publicly repeated what he claimed Barron Trump had said to former PresidentJoe Biden during the inauguration of President Donald … [+2164 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "JFK's grandson Jack Schlossberg to run for Congress",
#    'description': 'The Kennedy heir, who will be challenging for a New York seat, is best known for his outspoken political commentary online.',
#    'url': 'https://www.bbc.com/news/articles/c201yyd9zndo',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/386a/live/8ceb45b0-bf85-11f0-bda2-01f815d2809b.jpg',
#    'publishedAt': '2025-11-12T06:10:56Z',
#    'content': 'Jack Schlossberg, the grandson of John F. Kennedy, will run for US Congress, he told his supporters on Tuesday. \r\nThe only grandson to the late former president JFK, Schlossberg, 32, is best known fo… [+2494 chars]'},
#   {'source': {'id': None, 'name': 'Boing Boing'},
#    'author': 'Ellsworth Toohey',
#    'title': 'Trump claims anti-Trump content should be outlawed after Meyers segment',
#    'description': 'President "Poo-Poo" Trump attacked late-night host Seth Meyers on Saturday, calling him "the least talented person to \'perform\' live in the history of television" and declaring his show "100% ANTI TRUMP, WHICH IS PROBABLY ILLEGAL!!!" The outburst came after M…',
#    'url': 'https://boingboing.net/2025/11/03/trump-claims-anti-trump-content-should-be-outlawed-after-meyers-segment.html',
#    'urlToImage': None,
#    'publishedAt': '2025-11-03T20:49:14Z',
#    'content': 'President "Poo-Poo" Trump attacked late-night host Seth Meyers on Saturday, calling him "the least talented person to \'perform\' live in the history of television" and declaring his show "100% ANTI TR… [+559 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Matt Novak',
#    'title': 'Franklin the Turtle Becomes an AI Meme After Pete Hegseth Jokes About War Crimes',
#    'description': 'Even Republicans are calling for an investigation.',
#    'url': 'https://gizmodo.com/franklin-the-turtle-becomes-an-ai-meme-after-pete-hegseth-jokes-about-war-crimes-2000694015',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/12/pete-hegseth-franklin-war-crimes-1200x675.jpg',
#    'publishedAt': '2025-12-01T19:45:57Z',
#    'content': 'The Washington Post released a damning report over the holiday weekend that Defense Secretary Pete Hegseth has been ordering the military to commit war crimes in the Caribbean. Hegseth responded by p… [+6912 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Justine Calma',
#    'title': 'How deep-sea mining could threaten a vital ocean food source',
#    'description': 'The race to mine battery minerals from the ocean floor would create a new stream of waste that could rob sea life of a critical food source, according to new research published today in the journal Nature Communications. That could have far-reaching effects a…',
#    'url': 'https://www.theverge.com/news/814694/deep-sea-mining-waste-battery-metals-research-trump',
#    'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/11/gettyimages-1234090659.jpg?quality=90&strip=all&crop=0%2C10.736442418751%2C100%2C78.527115162497&w=1200',
#    'publishedAt': '2025-11-06T01:22:59Z',
#    'content': '<ul><li></li><li></li><li></li></ul>\r\nNew industry-backed research shows how waste from deep-sea mining could have far-reaching effects on fish and their food.\r\nNew industry-backed research shows how… [+9818 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'James Whitbrook',
#    'title': 'Oscar Isaac Would Come Back to ‘Star Wars’ If Disney Is Done Capitulating to Fascism',
#    'description': "The man behind Poe Dameron's X-Wing controls isn't giving up, as long as there's still light.",
#    'url': 'https://gizmodo.com/oscar-isaac-star-wars-return-disney-fascism-2000683691',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2025/11/oscar-isaac-star-wars-the-last-jedi-poe-dameron-1200x675.jpg',
#    'publishedAt': '2025-11-10T16:15:08Z',
#    'content': 'As Lucasfilm reworks and readjusts what has now become six years of waiting to see\xa0Star Warsreturn to movie theaters after The Rise of Skywalker, one question among many on fans’ lips has been just w… [+2818 chars]'},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': 'Alejandra Borunda',
#    'title': "Countries are gathering for climate negotiations. Here's where the U.S. stands",
#    'description': 'Under President Trump, the U.S. has taken steps to roll back climate policies. Here are six significant changes.',
#    'url': 'https://www.npr.org/2025/11/10/nx-s1-5601876/trump-cop30-climate-brazil-belem',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/1024x576+0+22/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F96%2F0f%2Fe5393aad48b492e3d0cfd4306a97%2Fgettyimages-2244367695.jpg',
#    'publishedAt': '2025-11-10T10:00:00Z',
#    'content': "Most of the world's nations are gathering in Brazil's northern city of Belém to negotiate the ongoing response to climate change. The United Nations annual climate summit, called COP30, begins Monday… [+8403 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': '
# %% [markdown]
# ### Preparing Lists for Keywords and News Providers
# Provider bias reference: https://mediabiasfactcheck.com/
# The text files of providers of the three categories are manually created by checking the above site with the provider ids we extracted in the previous cell.

# %%
# Left news providers
with open('left_prov.txt', 'r', encoding='utf-8') as f:
   left_prov = [line.strip() for line in f if line.strip()]
    
# Centre news providers
with open('centre_prov.txt', 'r', encoding='utf-8') as f:
    centre_prov = [line.strip() for line in f if line.strip()]
    
# Right news providers
with open('right_prov.txt', 'r', encoding='utf-8') as f:
    right_prov = [line.strip() for line in f if line.strip()]

# %% [markdown]
# ### Assign Keyword for search
# NewsAPI free account has a limit of 50 request per 12 hours.
# Therefore, only one keyword can be used at a time as we have 13 x 3 = 39 providers.
# Please check **key.txt** for all available key we generated.

# %%
keyword = input()
print(f"KEYWORD TO SEARCH = {keyword}")
# Out:
# KEYWORD TO SEARCH = tariff

# %% [markdown]
# ### Scraper

# %%
result_list_l = []
result_list_c = []
result_list_r = []

for provider in left_prov:
    url = (f'https://newsapi.org/v2/everything?'
           f'q={keyword}&'
           f'language=en&'
           f'sources={provider}&'
           f'apiKey={key}')
    response = requests.get(url)
    result = response.json()
    
    # check the API response status before storing the result
    if result.get("status") == "ok":
        for article in result["articles"]:
            result_list_l.append(article["url"])
    else:
        raise ValueError(f"API error: {result.get('message', 'Unknown error')}")

    
for provider in centre_prov:
    url = (f'https://newsapi.org/v2/everything?'
           f'q={keyword}&'
           f'language=en&'
           f'sources={provider}&'
           f'apiKey={key}')
    response = requests.get(url)
    result = response.json()
    
    # check the API response status before storing the result
    if result.get("status") == "ok":
        for article in result["articles"]:
            result_list_c.append(article["url"])
    else:
        raise ValueError(f"API error: {result.get('message', 'Unknown error')}")
    
for provider in right_prov:
    url = (f'https://newsapi.org/v2/everything?'
           f'q={keyword}&'
           f'language=en&'
           f'sources={provider}&'
           f'apiKey={key}')
    response = requests.get(url)
    result = response.json()
    
    # check the API response status before storing the result
    if result.get("status") == "ok":
        for article in result["articles"]:
            result_list_r.append(article["url"])
    else:
        raise ValueError(f"API error: {result.get('message', 'Unknown error')}")
    

print(len(list(set(result_list_l))))
print(len(list(set(result_list_c))))
print(len(list(set(result_list_r))))
# Out:
# 211
# 36
# 386

# %% [markdown]
# ### Data
# Combine the data (URLs) extracted into a singel csv file, label the data according to the provider bias.

# %%
left_articles = list(set(result_list_l))
centre_articles = list(set(result_list_c))
right_articles = list(set(result_list_r))

df_left = pd.DataFrame({'url': left_articles, 'label': 'left'})
df_centre = pd.DataFrame({'url': centre_articles, 'label': 'centre'})
df_right = pd.DataFrame({'url': right_articles, 'label': 'right'})

df_all = pd.concat([df_left, df_centre, df_right], ignore_index=True)
print(f"Total article count: {len(df_all)}")

# Check the dataset already there and store the current set as a new one
base_name = "dataset_"
suffix = 0
while os.path.exists(f"{base_name}{suffix}.csv"):
    suffix += 1

filename = f"{base_name}{suffix}.csv"

df_all.to_csv(filename, index=False, encoding='utf-8')
print(f"Saved to {filename}")
# Out:
# Total article count: 633
# Saved to dataset_0.csv

# %% [markdown]
# ### Actual News Content Scraper

# %%
# Choose the desired URLs dataset for content scraping
dataset_num = input()
INPUT_FILE = f"dataset_{dataset_num}.csv" 
OUTPUT_FILE = f"content_output/dataset_{dataset_num}_content.csv"
USER_AGENT = "Student-Assignment-Bot/1.5 (educational use)"

df = pd.read_csv(INPUT_FILE)
urls = df['url'].tolist()
labels = df['label'].tolist()

# %%
# Open a file for output, write the header
with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['content', 'label'])

# %%
for i, url in enumerate(urls):
    
    try:
        headers = {"User-Agent": USER_AGENT}
        response = requests.get(url, headers=headers, timeout=30, stream=True)
        text = None
        
        # Check if the response status is okay
        if response.status_code == 200:
            content_type = response.headers.get('Content-Type', '').lower()
            
            # Filter out pages that direct to a video or radio link
            if 'text' not in content_type and 'html' not in content_type:
                    response.close()
                    continue
            
            # Extract texts
            text = trafilatura.extract(response.text)
        
        # Clean out non necessary new lines.
        # Store None if no text is extracted
        clean_text = text.replace('\n', ' ').replace('\r', '') if text else None
        
        # Exclude the situation when no text is extracted
        # Store text into the ouput file with proper label
        if clean_text:
            with open(OUTPUT_FILE, 'a', newline='', encoding='utf-8') as f:
                writer = csv.writer(f) 
                writer.writerow([clean_text, labels[i]])
        
        # Print a message every 100 articles are processed, as this can take time 
        if i % 100 == 0:
            print(f"Processed {i}/{len(urls)} articles...")

        time.sleep(random.uniform(0.5, 1.5))

    # Print out failure URLs for easy debugging
    except Exception as e:
        print(f"Failed on {url}: {e}")
        time.sleep(2)
        continue

print(f"Content saved to {OUTPUT_FILE}")
# Out:
# Processed 0/633 articles...
# Processed 100/633 articles...
# Processed 200/633 articles...
# Processed 300/633 articles...
# Processed 400/633 articles...
# Processed 500/633 articles...
# Processed 600/633 articles...
# Content saved to content_output/dataset_0_content.csv

# %% [markdown]
# ### Combining Content Output
# Remove duplicated entries

# %%
output_folder = "final_dataset"
os.makedirs(output_folder, exist_ok=True)
files = glob.glob("content_output/*.csv")

dfs = []
for f in files:
    df = pd.read_csv(f, skiprows=1, names=["content", "label"])
    dfs.append(df)

combined = pd.concat(dfs, ignore_index=True)
combined = combined.drop_duplicates(subset="content")

# Print out total entries of each category and the final total
label_counts = combined["label"].value_counts()
print("Counts per label:")
print(label_counts)
print(f"Total entries: {len(combined)}")

filename = os.path.join(output_folder, "final_dataset.csv")
combined.to_csv(filename, index=False, encoding='utf-8')
# Out:
# Counts per label:
# label
# right     372
# left      189
# centre     34
# Name: count, dtype: int64
# Total entries: 595

# %% [markdown]
# ### Normalise between all three categories
# This cell is used to extract the first 3200 articles from each catefory to balance the entry and prevent bias during training.

# %%
df = pd.read_csv("final_dataset/final_dataset.csv")

labels = ["left", "centre", "right"]

# Use 32 here for demonstration
# We use 3200 during the actual scrpaing process
n = 32

subsets = {}

for label in labels:
    subset = df[df["label"] == label].head(n)
    filename = f"final_dataset/balanced_{label}.csv"
    subset.to_csv(filename, index=False)
    subsets[label] = subset

combined = pd.concat(subsets.values(), ignore_index=True)

combined.to_csv("final_dataset/balanced_all.csv", index=False)
